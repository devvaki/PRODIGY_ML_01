# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('housing.csv')

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split
X=data.drop(['median_house_value'],axis=1)
y=data['median_house_value']

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 6542     -118.06     34.03                36.0         21.0             7.0
# 1666     -122.25     38.03                15.0       3338.0           532.0
# 2116     -119.72     36.75                11.0       4832.0           993.0
# 13406    -117.46     34.09                 8.0       4711.0           963.0
# 19254    -122.75     38.46                13.0       4323.0          1020.0
# ...          ...       ...                 ...          ...             ...
# 3285     -122.78     39.05                15.0       1601.0           323.0
# 14047    -117.13     32.76                29.0       2568.0           682.0
# 10746    -117.88     33.63                21.0       9565.0          2289.0
# 12772    -121.42     38.63                42.0       2217.0           536.0
# 1986     -119.81     36.73                51.0        956.0           196.0
#
#        population  households  median_income ocean_proximity  \
# 6542         21.0         9.0         2.3750       <1H OCEAN
# 1666       1834.0       520.0         5.6293        NEAR BAY
# 2116       2190.0       888.0         2.6611          INLAND
# 13406      3310.0       988.0         3.5488          INLAND
# 19254      2566.0       728.0         3.0147       <1H OCEAN
# ...           ...         ...            ...             ...
# 3285        661.0       269.0         2.6181          INLAND
# 14047      1191.0       642.0         2.1094      NEAR OCEAN
# 10746      3162.0      1831.0         4.7024       <1H OCEAN
# 12772      1203.0       507.0         1.9412          INLAND
# 1986        662.0       180.0         2.1010          INLAND
#
#        median_house_value
# 6542             175000.0
# 1666             197600.0
# 2116              74700.0
# 13406            101600.0
# 19254            142800.0
# ...                   ...
# 3285             108900.0
# 14047            162500.0
# 10746            345400.0
# 12772             73100.0
# 1986              56700.0
#
# [15324 rows x 10 columns]

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.corr(numeric_only=True)
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924022           -0.111576     0.046766
# latitude            -0.924022  1.000000            0.012991    -0.039128
# housing_median_age  -0.111576  0.012991            1.000000    -0.358586
# total_rooms          0.046766 -0.039128           -0.358586     1.000000
# total_bedrooms       0.072246 -0.071221           -0.318141     0.927863
# population           0.101936 -0.111645           -0.290670     0.853826
# households           0.059708 -0.076853           -0.299344     0.917805
# median_income       -0.017530 -0.078380           -0.119851     0.206734
# median_house_value  -0.051895 -0.139734            0.110689     0.132790
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.072246    0.101936    0.059708      -0.017530
# latitude                 -0.071221   -0.111645   -0.076853      -0.078380
# housing_median_age       -0.318141   -0.290670   -0.299344      -0.119851
# total_rooms               0.927863    0.853826    0.917805       0.206734
# total_bedrooms            1.000000    0.874596    0.980441      -0.004945
# population                0.874596    1.000000    0.903408       0.009208
# households                0.980441    0.903408    1.000000       0.017043
# median_income            -0.004945    0.009208    0.017043       1.000000
# median_house_value        0.045466   -0.030268    0.060836       0.690749
#
#                     median_house_value
# longitude                    -0.051895
# latitude                     -0.139734
# housing_median_age            0.110689
# total_rooms                   0.132790
# total_bedrooms                0.045466
# population                   -0.030268
# households                    0.060836
# median_income                 0.690749
# median_house_value            1.000000

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(numeric_only=True), annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %%
train_data['total_rooms']=np.log(train_data['total_rooms']+1)
train_data['total_bedrooms']=np.log(train_data['total_bedrooms']+1)
train_data['population']=np.log(train_data['population']+1)
train_data['households']=np.log(train_data['households']+1)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     6778
# INLAND        4840
# NEAR OCEAN    1995
# NEAR BAY      1708
# ISLAND           3
# Name: count, dtype: int64

# %%
pd.get_dummies(train_data.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 6542        True   False   False     False       False
# 1666       False   False   False      True       False
# 2116       False    True   False     False       False
# 13406      False    True   False     False       False
# 19254       True   False   False     False       False
# ...          ...     ...     ...       ...         ...
# 3285       False    True   False     False       False
# 14047      False   False   False     False        True
# 10746       True   False   False     False       False
# 12772      False    True   False     False       False
# 1986       False    True   False     False       False
#
# [15324 rows x 5 columns]

# %%
train_data.join(pd.get_dummies(train_data.ocean_proximity))
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 6542     -118.06     34.03                36.0     3.091042        2.079442
# 1666     -122.25     38.03                15.0     8.113427        6.278521
# 2116     -119.72     36.75                11.0     8.483223        6.901737
# 13406    -117.46     34.09                 8.0     8.457868        6.871091
# 19254    -122.75     38.46                13.0     8.371936        6.928538
# ...          ...       ...                 ...          ...             ...
# 3285     -122.78     39.05                15.0     7.379008        5.780744
# 14047    -117.13     32.76                29.0     7.851272        6.526495
# 10746    -117.88     33.63                21.0     9.165970        7.736307
# 12772    -121.42     38.63                42.0     7.704361        6.285998
# 1986     -119.81     36.73                51.0     6.863803        5.283204
#
#        population  households  median_income ocean_proximity  \
# 6542     3.091042    2.302585         2.3750       <1H OCEAN
# 1666     7.514800    6.255750         5.6293        NEAR BAY
# 2116     7.692113    6.790097         2.6611          INLAND
# 13406    8.105006    6.896694         3.5488          INLAND
# 19254    7.850493    6.591674         3.0147       <1H OCEAN
# ...           ...         ...            ...             ...
# 3285     6.495266    5.598422         2.6181          INLAND
# 14047    7.083388    6.466145         2.1094      NEAR OCEAN
# 10746    8.059276    7.513164         4.7024       <1H OCEAN
# 12772    7.093405    6.230481         1.9412          INLAND
# 1986     6.496775    5.198497         2.1010          INLAND
#
#        median_house_value  <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 6542             175000.0       True   False   False     False       False
# 1666             197600.0      False   False   False      True       False
# 2116              74700.0      False    True   False     False       False
# 13406            101600.0      False    True   False     False       False
# 19254            142800.0       True   False   False     False       False
# ...                   ...        ...     ...     ...       ...         ...
# 3285             108900.0      False    True   False     False       False
# 14047            162500.0      False   False   False     False        True
# 10746            345400.0       True   False   False     False       False
# 12772             73100.0      False    True   False     False       False
# 1986              56700.0      False    True   False     False       False
#
# [15324 rows x 15 columns]

# %%
train_data=train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 6542     -118.06     34.03                36.0     3.091042        2.079442
# 1666     -122.25     38.03                15.0     8.113427        6.278521
# 2116     -119.72     36.75                11.0     8.483223        6.901737
# 13406    -117.46     34.09                 8.0     8.457868        6.871091
# 19254    -122.75     38.46                13.0     8.371936        6.928538
# ...          ...       ...                 ...          ...             ...
# 3285     -122.78     39.05                15.0     7.379008        5.780744
# 14047    -117.13     32.76                29.0     7.851272        6.526495
# 10746    -117.88     33.63                21.0     9.165970        7.736307
# 12772    -121.42     38.63                42.0     7.704361        6.285998
# 1986     -119.81     36.73                51.0     6.863803        5.283204
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 6542     3.091042    2.302585         2.3750            175000.0       True
# 1666     7.514800    6.255750         5.6293            197600.0      False
# 2116     7.692113    6.790097         2.6611             74700.0      False
# 13406    8.105006    6.896694         3.5488            101600.0      False
# 19254    7.850493    6.591674         3.0147            142800.0       True
# ...           ...         ...            ...                 ...        ...
# 3285     6.495266    5.598422         2.6181            108900.0      False
# 14047    7.083388    6.466145         2.1094            162500.0      False
# 10746    8.059276    7.513164         4.7024            345400.0       True
# 12772    7.093405    6.230481         1.9412             73100.0      False
# 1986     6.496775    5.198497         2.1010             56700.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 6542    False   False     False       False
# 1666    False   False      True       False
# 2116     True   False     False       False
# 13406    True   False     False       False
# 19254   False   False     False       False
# ...       ...     ...       ...         ...
# 3285     True   False     False       False
# 14047   False   False     False        True
# 10746   False   False     False       False
# 12772    True   False     False       False
# 1986     True   False     False       False
#
# [15324 rows x 14 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(numeric_only=True), annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="latitude", y="longitude", data=train_data, hue="median_house_value", palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data['bedroom_ratio']=train_data['total_bedrooms']/ train_data['total_rooms']
train_data['household_rooms']=train_data['total_rooms']/ train_data['households']

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(numeric_only=True), annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train, y_train = train_data.drop(['median_house_value'],axis=1),train_data['median_house_value']
X_train_s=scaler.fit_transform(X_train)
reg=LinearRegression()
reg.fit(X_train_s, y_train)
# Out:
# LinearRegression()

# %%
test_data=X_test.join(y_test)

test_data['total_rooms']=np.log(test_data['total_rooms']+1)
test_data['total_bedrooms']=np.log(test_data['total_bedrooms']+1)
test_data['population']=np.log(test_data['population']+1)
test_data['households']=np.log(test_data['households']+1)

test_data=test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)
test_data['bedroom_ratio']=test_data['total_bedrooms']/ test_data['total_rooms']
test_data['household_rooms']=test_data['total_rooms']/ test_data['households']

# %%
X_test, y_test = test_data.drop(['median_house_value'],axis=1),test_data['median_house_value']

# %%
X_test_s=scaler.transform(X_test)

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4099     -118.37     34.14                 8.0     8.385489        7.353082
# 19652    -120.86     37.50                34.0     8.360071        6.904751
# 16113    -122.50     37.75                46.0     7.740230        6.126869
# 14115    -117.11     32.73                35.0     7.432484        5.986452
# 4710     -118.35     34.05                33.0     7.965893        6.729824
# ...          ...       ...                 ...          ...             ...
# 19345    -122.82     38.64                29.0     7.685703        5.955837
# 5265     -118.54     34.05                33.0     8.821585        6.996681
# 8709     -118.35     33.85                34.0     7.479300        5.676754
# 10607    -117.78     33.68                15.0     7.514800        5.802118
# 1838     -122.30     37.90                30.0     7.480428        6.156979
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 4099     7.668094    7.252762         3.5714            197900.0       True
# 19652    7.978311    6.870053         1.9829             82800.0      False
# 16113    7.265430    6.169611         4.0217            272400.0      False
# 14115    7.035269    5.905362         2.3269             97300.0      False
# 4710     7.256297    6.602588         2.6781            328800.0       True
# ...           ...         ...            ...                 ...        ...
# 19345    7.019297    5.926926         3.8681            188600.0       True
# 5265     7.840313    6.959399         8.5650            500001.0       True
# 8709     6.821107    5.669881         5.0000            354200.0       True
# 10607    6.735780    5.736572         6.0634            234300.0       True
# 1838     6.781058    6.082219         2.2672            162500.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 4099    False   False     False       False       0.876882         1.156179
# 19652    True   False     False       False       0.825920         1.216886
# 16113   False   False     False        True       0.791562         1.254573
# 14115   False   False     False        True       0.805444         1.258599
# 4710    False   False     False       False       0.844830         1.206480
# ...       ...     ...       ...         ...            ...              ...
# 19345   False   False     False       False       0.774924         1.296744
# 5265    False   False     False       False       0.793132         1.267579
# 8709    False   False     False       False       0.758995         1.319128
# 10607   False   False     False       False       0.772092         1.309981
# 1838    False   False      True       False       0.823078         1.229885
#
# [5109 rows x 16 columns]

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 6542     -118.06     34.03                36.0     3.091042        2.079442
# 1666     -122.25     38.03                15.0     8.113427        6.278521
# 2116     -119.72     36.75                11.0     8.483223        6.901737
# 13406    -117.46     34.09                 8.0     8.457868        6.871091
# 19254    -122.75     38.46                13.0     8.371936        6.928538
# ...          ...       ...                 ...          ...             ...
# 3285     -122.78     39.05                15.0     7.379008        5.780744
# 14047    -117.13     32.76                29.0     7.851272        6.526495
# 10746    -117.88     33.63                21.0     9.165970        7.736307
# 12772    -121.42     38.63                42.0     7.704361        6.285998
# 1986     -119.81     36.73                51.0     6.863803        5.283204
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 6542     3.091042    2.302585         2.3750            175000.0       True
# 1666     7.514800    6.255750         5.6293            197600.0      False
# 2116     7.692113    6.790097         2.6611             74700.0      False
# 13406    8.105006    6.896694         3.5488            101600.0      False
# 19254    7.850493    6.591674         3.0147            142800.0       True
# ...           ...         ...            ...                 ...        ...
# 3285     6.495266    5.598422         2.6181            108900.0      False
# 14047    7.083388    6.466145         2.1094            162500.0      False
# 10746    8.059276    7.513164         4.7024            345400.0       True
# 12772    7.093405    6.230481         1.9412             73100.0      False
# 1986     6.496775    5.198497         2.1010             56700.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 6542    False   False     False       False       0.672731         1.342423
# 1666    False   False      True       False       0.773843         1.296955
# 2116     True   False     False       False       0.813575         1.249352
# 13406    True   False     False       False       0.812390         1.226365
# 19254   False   False     False       False       0.827591         1.270077
# ...       ...     ...       ...         ...            ...              ...
# 3285     True   False     False       False       0.783404         1.318051
# 14047   False   False     False        True       0.831266         1.214212
# 10746   False   False     False       False       0.844025         1.219988
# 12772    True   False     False       False       0.815901         1.236560
# 1986     True   False     False       False       0.769720         1.320344
#
# [15324 rows x 16 columns]

# %%
X_test_s=scaler.transform(X_test)

# %%
reg.score(X_test, y_test)
# Out:
# C:\Users\anarg\anaconda3\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# -2236.55639313601

# %%
X_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4099     -118.37     34.14                 8.0     8.385489        7.353082
# 19652    -120.86     37.50                34.0     8.360071        6.904751
# 16113    -122.50     37.75                46.0     7.740230        6.126869
# 14115    -117.11     32.73                35.0     7.432484        5.986452
# 4710     -118.35     34.05                33.0     7.965893        6.729824
# ...          ...       ...                 ...          ...             ...
# 19345    -122.82     38.64                29.0     7.685703        5.955837
# 5265     -118.54     34.05                33.0     8.821585        6.996681
# 8709     -118.35     33.85                34.0     7.479300        5.676754
# 10607    -117.78     33.68                15.0     7.514800        5.802118
# 1838     -122.30     37.90                30.0     7.480428        6.156979
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 4099     7.668094    7.252762         3.5714       True   False   False
# 19652    7.978311    6.870053         1.9829      False    True   False
# 16113    7.265430    6.169611         4.0217      False   False   False
# 14115    7.035269    5.905362         2.3269      False   False   False
# 4710     7.256297    6.602588         2.6781       True   False   False
# ...           ...         ...            ...        ...     ...     ...
# 19345    7.019297    5.926926         3.8681       True   False   False
# 5265     7.840313    6.959399         8.5650       True   False   False
# 8709     6.821107    5.669881         5.0000       True   False   False
# 10607    6.735780    5.736572         6.0634       True   False   False
# 1838     6.781058    6.082219         2.2672      False   False   False
#
#        NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 4099      False       False       0.876882         1.156179
# 19652     False       False       0.825920         1.216886
# 16113     False        True       0.791562         1.254573
# 14115     False        True       0.805444         1.258599
# 4710      False       False       0.844830         1.206480
# ...         ...         ...            ...              ...
# 19345     False       False       0.774924         1.296744
# 5265      False       False       0.793132         1.267579
# 8709      False       False       0.758995         1.319128
# 10607     False       False       0.772092         1.309981
# 1838       True       False       0.823078         1.229885
#
# [5109 rows x 15 columns]

# %%
y_test
# Out:
# 4099     197900.0
# 19652     82800.0
# 16113    272400.0
# 14115     97300.0
# 4710     328800.0
#            ...
# 19345    188600.0
# 5265     500001.0
# 8709     354200.0
# 10607    234300.0
# 1838     162500.0
# Name: median_house_value, Length: 5109, dtype: float64

# %%
from sklearn.ensemble import RandomForestRegressor
forest = RandomForestRegressor()
forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test, y_test)
# Out:
# 0.8113342985799112

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
forest=RandomForestRegressor()
param_grid={
    "n_estimators":[60,80,100],
    "max_features":[14,18,20],
    "min_samples_split":[2,4,6,8]
}
grid_search = GridSearchCV(forest, param_grid, cv=5,
                           scoring="neg_mean_squared_error",
                           return_train_score=True)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': [14, 18, 20],
#                          'min_samples_split': [2, 4, 6, 8],
#                          'n_estimators': [60, 80, 100]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(max_features=12)

# %%
best_forest = grid_search.best_estimator_

# %%
best_forest.score(X_test_s, y_test)
# Out:
# C:\Users\anarg\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# 0.0058276867754846196

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
forest=RandomForestRegressor()
param_grid={
    "n_estimators":[100,200,300],
    "min_samples_split":[2,4],
    "max_depth":[None,4,8]
}
grid_search = GridSearchCV(forest, param_grid, cv=5,
                           scoring="neg_mean_squared_error",
                           return_train_score=True)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [None, 4, 8], 'min_samples_split': [2, 4],
#                          'n_estimators': [100, 200, 300]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(n_estimators=300)

# %%
grid_search.best_estimator_.score(X_test_s, y_test)
# Out:
# C:\Users\anarg\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# 0.03667732504611043
